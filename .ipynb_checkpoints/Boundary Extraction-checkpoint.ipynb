# %% [markdown]
# # Boundary Extraction
#
# Since we are not using all of Zambia, I need to extract the boundaries that are used in the analysis
#
#
# https://gaez.fao.org/datasets/hqfao::agro-ecological-regions-of-zambia/about

# %%
from utils.proj_utils import set_proj_data_directory

set_proj_data_directory()
# Out:
# PROJ data directory has been successfully set.
# /Users/samuelgartenstein/anaconda3/lib/python3.11/site-packages/pyproj/__init__.py:96: UserWarning: Valid PROJ data directory not found. Either set the path using the environmental variable PROJ_DATA (PROJ 9.1+) | PROJ_LIB (PROJ<9.1) or with `pyproj.datadir.set_data_dir`.
#   warnings.warn(str(err))

# %%
import pandas as pd 
import geopandas as gpd
import matplotlib.pyplot as plt
import ee
import geemap


from utils.preprocessing import load_fao_gaul_data

# %%
ee.Authenticate()
ee.Initialize(project='ee-sg4283') #Replace with your ID
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Loading Zambia Boundaries
#
# ### Admin 0 Level
#
# This is to extract data from all of Zambia

# %%
# Load Zambia at Level 0
zambia_gdf, counties_list_level0 = load_fao_gaul_data(admin_level="level0")
print(counties_list_level0)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['Zambia']

# %%
# Load Zambia at Level 2
zambia_gdf_2, counties_list_level2 = load_fao_gaul_data(admin_level="level2")
print(counties_list_level2)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ...

# %%
def plot_fao_gaul(gdf, admin_level, country_name="Zambia"):
    """
    Plot FAO GAUL administrative boundaries using Matplotlib.

    Parameters:
    - gdf (gpd.GeoDataFrame): GeoDataFrame containing the administrative boundaries.
    - admin_level (str): Administrative level (e.g., "level0", "level2").
    - country_name (str): Country name (default: "Zambia").
    """
    if gdf is None or gdf.empty:
        print(f"Error: No data available for {country_name} at {admin_level}.")
        return

    # Create the plot
    fig, ax = plt.subplots(figsize=(10, 8))
    
    # Plot administrative boundaries
    gdf.plot(ax=ax, edgecolor='black', facecolor='lightgray')
    
    # Customize plot
    ax.set_title(f"FAO GAUL {admin_level.upper()} - {country_name}", fontsize=14)
    ax.set_xlabel("Longitude")
    ax.set_ylabel("Latitude")
    plt.grid(True)
    
    # Show plot
    plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
plot_fao_gaul(zambia_gdf, admin_level="level0")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
plot_fao_gaul(zambia_gdf_2, admin_level="level2")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Agro-Ecological  Boundaries

# %%
# Define the file path
file_path = "data/Agro-ecological_regions_of_Zambia.geojson"

# Read the GeoJSON file
agro_ecol_gdf = gpd.read_file(file_path)

# Plot
agro_ecol_gdf.plot()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <Axes: >

# %% [markdown]
# ### Select Boundaries
#
# We will only use agro-ecological zones I, IIa, and IIb. We will exclude III since droughts do not affect the North as severely as the South.

# %%
# Load agro-ecological zones (assuming `zambia_gdf` contains these zones)
# Filter for regions I, IIB, and IIA
selected_zones = agro_ecol_gdf[agro_ecol_gdf["AGRO_ECOL_"].isin(["I", "IIB", "IIA"])]

# Display the filtered regions
print(selected_zones)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#    FID AGRO_ECOL_  COUNT_  Area   Shape__Area  Shape__Length  \
# 0    1          I      21     0  1.292624e+11   3.349991e+06
# 1    2        IIB      28     0  2.111927e+11   4.171581e+06
# ...

# %%
# Create a plot
fig, ax = plt.subplots(figsize=(10, 8))

# Plot the full Zambia boundary
zambia_gdf.plot(ax=ax, edgecolor='black', facecolor='lightgray', linewidth=1, label="Zambia Boundary")

# Overlay the selected agro-ecological zones with a different color
selected_zones.plot(ax=ax, edgecolor='red', facecolor='none', linewidth=2, label="Selected Zones (I, IIA, IIB)")

# Customize the plot
ax.set_title("Zambia Agro-Ecological Zones Overlay", fontsize=14)
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
ax.legend()
plt.grid(True)

# Show the plot
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# /var/folders/kb/wc8mw5490w942nfv1syxgqjc0000gn/T/ipykernel_27866/1167970617.py:14: UserWarning: Legend does not support handles for PatchCollection instances.
# ...

# %% [markdown]
# ### Outer Boundary
#
# - Extracts the outer boundaires of the zones
#
# - TODO: Ask Max about not fitting perfectly to Zambia

# %%
# Dissolve the internal boundaries to create a single outer boundary
outer_boundary = selected_zones.dissolve()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Create the plot
fig, ax = plt.subplots(figsize=(10, 8))

# Plot the full Zambia boundary
zambia_gdf_2.plot(ax=ax, edgecolor='black', facecolor='lightgray', linewidth=1, label="Zambia Boundary")

# Overlay the dissolved agro-ecological zones with a distinct color
outer_boundary.plot(ax=ax, color="none", edgecolor="red", linewidth=2, label="Agro-Ecological Zones (I, IIA, IIB)")

# Customize the plot
ax.set_title("Dissolved Agro-Ecological Regions I, IIA, and IIB", fontsize=14)
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
ax.legend()
plt.grid(True)

# Show the plot
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# /var/folders/kb/wc8mw5490w942nfv1syxgqjc0000gn/T/ipykernel_27866/782869545.py:14: UserWarning: Legend does not support handles for PatchCollection instances.
# ...

# %% [markdown]
# ## Overlaps

# %%
# Create a new column indicating whether an admin2 boundary falls within the outer boundary
zambia_gdf_2["within_agro_zone"] = zambia_gdf_2.geometry.within(outer_boundary.unary_union)

# Calculate the intersection area between admin2 boundaries and the agro-ecological zones
zambia_gdf_2["intersection_area"] = zambia_gdf_2.geometry.intersection(outer_boundary.unary_union).area

# Calculate the percentage of each admin2 region that falls within the agro-ecological zone
zambia_gdf_2["percentage_within_agro_zone"] = (zambia_gdf_2["intersection_area"] / zambia_gdf_2.geometry.area) * 100
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# /var/folders/kb/wc8mw5490w942nfv1syxgqjc0000gn/T/ipykernel_27866/4161595480.py:2: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
# ...

# %%
zambia_gdf_2
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                                              geometry  ADM0_CODE ADM0_NAME  \
# 0   POLYGON ((27.1826 -14.54599, 27.18318 -14.5580...        270    Zambia
# ...

# %%
# Filter the DataFrame for values greater than zero
filtered_df = zambia_gdf_2[zambia_gdf_2['percentage_within_agro_zone'] > 0]

# Sort the filtered DataFrame in descending order by percentage_within_agro_zone
filtered_sorted_df = filtered_df.sort_values(by='percentage_within_agro_zone', ascending=False)

# Loop through the sorted DataFrame and print the values
for _, row in filtered_sorted_df.iterrows():
    print(f"ADM2_NAME: {row['ADM2_NAME']}, Percentage: {row['percentage_within_agro_zone']:.2f}%")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ADM2_NAME: Itezhi-tezhi, Percentage: 100.00%
# ADM2_NAME: Mazabuka, Percentage: 100.00%
# ADM2_NAME: Monze, Percentage: 100.00%
# ADM2_NAME: Mambwe, Percentage: 100.00%
# ADM2_NAME: Mumbwa, Percentage: 100.00%
# ...

# %%
import folium

# Create a folium map centered on Zambia
m = folium.Map(location=[-13.1339, 27.8493], zoom_start=6)

# Add a choropleth layer for percentage within agro zone
folium.Choropleth(
    geo_data=zambia_gdf_2,
    name="Percentage Within Agro Zone",
    data=zambia_gdf_2,
    columns=["ADM2_NAME", "percentage_within_agro_zone"],
    key_on="feature.properties.ADM2_NAME",
    fill_color="YlGnBu",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="Percentage of Admin2 within Agro Zone (%)",
).add_to(m)

# Add markers for each Admin2 boundary center with tooltips
for idx, row in zambia_gdf_2.iterrows():
    centroid = row.geometry.centroid
    folium.Marker(
        location=[centroid.y, centroid.x],
        tooltip=f"{row['ADM2_NAME']}: {row['percentage_within_agro_zone']:.2f}%",
        icon=folium.Icon(color="blue", icon="info-sign")
    ).add_to(m)

# Add the agro-ecological outer boundary as a red polyline
for geom in outer_boundary.geometry:
    if geom.geom_type == "Polygon":
        coords = list(geom.exterior.coords)
        folium.PolyLine(
            locations=[(lat, lon) for lon, lat in coords],  # Ensure lat/lon order
            color="red",
            weight=2,
            popup="Agro-Ecological Zones"
        ).add_to(m)

# Add layer control
folium.LayerControl().add_to(m)

# Display the interactive map
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ...

# %% [markdown]
# Itezhi-tezhi, Percentage: 100.00%
#
# Mazabuka, Percentage: 100.00%
#
# Monze, Percentage: 100.00%
#
# Mambwe, Percentage: 100.00%
#
# Mumbwa, Percentage: 100.00%
#
# Chongwe, Percentage: 100.00%
#
# Senanga, Percentage: 100.00%
#
# Mongu, Percentage: 100.00%
#
# Namwala, Percentage: 100.00%
#
# Kabwe, Percentage: 100.00%
#
# Choma, Percentage: 100.00%
#
# Chibombo, Percentage: 100.00%
#
# Lusaka, Percentage: 100.00%
#
# Katete, Percentage: 100.00%
#
# Petauke, Percentage: 99.44%
#
# Lundazi, Percentage: 99.39%
#
# Kaoma, Percentage: 98.70%
#
# Shang'ombo, Percentage: 98.54%
#
# Kalabo, Percentage: 98.54%
#
# Chipata, Percentage: 98.16%
#
# Kapiri-Mposhi, Percentage: 98.15%
#
# Nyimba, Percentage: 97.90%
#
# Sesheke, Percentage: 97.63%
#
# Kalomo, Percentage: 97.03%
#
# Kazungula, Percentage: 95.34%
#
# Kafue, Percentage: 94.24%
#
# Chama, Percentage: 92.76%
#
# Luangwa, Percentage: 90.12%
#
# Chadiza, Percentage: 88.93%
#
# Livingstone, Percentage: 86.77%
#
# Gwembe, Percentage: 85.04%
#
# Mkushi, Percentage: 82.10%
#
# Siavonga, Percentage: 81.07%
#
# Sinazongwe, Percentage: 72.21% (KEEP)

# %%
# Filter the DataFrame for values 70% and above
zambia_gdf_2_filtered = zambia_gdf_2[zambia_gdf_2['percentage_within_agro_zone'] >= 70]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import geopandas as gpd

# Set projection
proj = ccrs.PlateCarree()

# Create figure and axis
fig, ax = plt.subplots(figsize=(10, 10), subplot_kw={'projection': proj})

# Add features: borders, coastlines, land
ax.add_feature(cfeature.BORDERS, linestyle=':', edgecolor='gray')
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.LAND, edgecolor='black', facecolor='lightgray')

# Plot Zambia's agro-zone filtered areas in a solid blue color
zambia_gdf_2_filtered.plot(
    color="#4A90E2",  # Nice shade of blue
    edgecolor="black",
    linewidth=0.5,
    ax=ax
)

# Set title
ax.set_title("Zambia Districts with Agro-Zone Percentage ≥ 70%", fontsize=14)

# Show plot
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Dissolve the geometries to get the outer boundary
magz_outer_boundary = zambia_gdf_2_filtered.dissolve()

# Set projection
proj = ccrs.PlateCarree()

# Create figure and axis
fig, ax = plt.subplots(figsize=(10, 10), subplot_kw={'projection': proj})

# Add features: borders, coastlines, land
ax.add_feature(cfeature.BORDERS, linestyle=':', edgecolor='gray')
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.LAND, edgecolor='black', facecolor='lightgray')

# Plot Zambia's agro-zone filtered districts in blue
zambia_gdf_2_filtered.plot(
    color="#4A90E2",  # Nice shade of blue
    edgecolor="black",
    linewidth=0.5,
    ax=ax
)

# Plot the outer boundary in red
magz_outer_boundary.plot(
    edgecolor="red",
    facecolor="none",
    linewidth=2,
    ax=ax
)

# Set title
ax.set_title("Zambia Districts with Agro-Zone Percentage ≥ 70% (with Outer Boundary)", fontsize=14)

# Show plot
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Exporting Boundaries

# %%
'''
Zambia Boundary Output
'''

# Define the output file path for export
zambia_output_path = "data/boundaries/zambia_boundary.geojson"

# Save the dissolved (outer boundary) as a new GeoJSON file
zambia_gdf.to_file(zambia_output_path, driver="GeoJSON")

# Confirm successful export
print(f"Exported outer boundary to {zambia_output_path}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Exported outer boundary to data/boundaries/zambia_boundary.geojson

# %%
'''
Zambia Admin2 Boundary Output
'''

# Define the output file path for export
zambia_admin2_output_path = "data/boundaries/zambia_admin2_boundaries.geojson"

# Save the dissolved (outer boundary) as a new GeoJSON file
zambia_gdf_2.to_file(zambia_admin2_output_path, driver="GeoJSON")

# Confirm successful export
print(f"Exported outer boundary to {zambia_admin2_output_path}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Exported outer boundary to data/boundaries/zambia_admin2_boundaries.geojson

# %%
'''
Modified Agro-Ecological Outer Boundary Output
'''

# Define the output file path for export
magz_output_path = "data/boundaries/mod_agro_eco_outer_boundary.geojson"

# Save the dissolved (outer boundary) as a new GeoJSON file
magz_outer_boundary.to_file(magz_output_path, driver="GeoJSON")

# Confirm successful export
print(f"Exported outer boundary to {magz_output_path}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Exported outer boundary to data/boundaries/mod_agro_eco_outer_boundary.geojson

# %% [markdown]
# ### Map wtih Geographical Features for Paper

# %%
# Set projection
proj = ccrs.PlateCarree()

# Create figure and axis
fig, ax = plt.subplots(figsize=(10, 10), subplot_kw={'projection': proj})

# Add geographic features
ax.add_feature(cfeature.BORDERS, linestyle=':', edgecolor='gray')
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.LAND, edgecolor='black', facecolor='lightgray')
#ax.add_feature(cfeature.LAKES, alpha=0.5, facecolor='lightblue', edgecolor='gray')
ax.add_feature(cfeature.RIVERS, edgecolor='lightblue', linewidth=0.6)

# Plot Zambia districts outline only
zambia_gdf_2_filtered.plot(
    facecolor="none",       # No fill
    edgecolor="black",
    linewidth=0.5,
    ax=ax
)

# Set title
ax.set_title("Southern Zambia: District Boundaries with Rivers and Lakes", fontsize=14)

# Show plot
plt.show()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
