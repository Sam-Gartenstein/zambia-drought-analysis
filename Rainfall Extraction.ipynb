# %% [markdown]
# # Zambia Rainfall Extraction
#
# Notebook for extracting CHIRPS pixel data for Zambia.

# %%
import time
import os
import shutil
import numpy as np
import geemap
import ee
import geopandas as gpd
import json

# %%
# Authenticate Earth Engine API
ee.Authenticate()

# Initialize the Earth Engine API
ee.Initialize(project='ee-sg4283')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Load the outer boundary GeoJSON
outer_boundary_gdf = gpd.read_file("data/Agro_ecological_regions_Zambia_outer_boundary.geojson")
print(outer_boundary_gdf)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#    FID AGRO_ECOL_  COUNT_  Area   Shape__Area  Shape__Length  \
# 0    1          I      21     0  1.292624e+11   3.349991e+06
#
#                                             geometry
# 0  POLYGON ((30.23312 -15.17910, 30.26592 -15.250...

# %% [markdown]
# ### Feature Collection

# %%
# Convert the GeoDataFrame to a GeoJSON-like dictionary
geojson_dict = json.loads(outer_boundary_gdf.to_json())

# Convert to an Earth Engine FeatureCollection
ee_feature_collection = ee.FeatureCollection(geojson_dict)

# Print to confirm
print(ee_feature_collection.getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'type': 'FeatureCollection', 'columns': {'AGRO_ECOL_': 'String', 'Area': 'Integer', 'COUNT_': 'Integer', 'FID': 'Integer', 'Shape__Area': 'Float', 'Shape__Length': 'Float', 'system:index': 'String'}, 'features': [{'type': 'Feature', 'geometry': {'type': 'Polygon', 'coordinates': [[[30.233121, -15.1791], [30.19756408464676, -15.051614165913099], [30.2136894404691, -15.0208402152104], [30.220739072085, -15.0073865576162], [30.2182521820068, -15], [30.2173194885254, -14.9972333908081], [30.2243156433105, -14.9949712753296], [30.2278422255722, -14.9938307578151], [30.23271, -14.984541], [30.340876, -14.926211], [30.452107, -14.879294], [30.609289, -14.831909], [30.689267, -14.80534], [30.772214, -14.784464], [30.869376, -14.754859], [30.935043, -14.731298], [31.009471, -14.716231], [31.098113, -14.692436], [31.1841423399, -14.6835081881693], [31.1885738372803, -14.6799917221069], [31.2293510437012, -14.668948173523], [31.2667942047119, -14.6588010787964], [31.325231552124, -14.6499557495117], [31.3525886535645, -14.6439008712769], [31.3562164306641, -14.6430978775025], [31.3781412952313, -14.6382407908199], [31.41583, -14.626242], [31.504376, -14.596725], [31.5432082758203, -14.583359379749], [31.5475959777832, -14.5803022384644], [31.595401763916, -14.5542411804199], [31.5998935699463, -14.5517921447754], [31.6058120727539, -14.5502586364746], [31.6388893127441, -14.5290775299072], [31.6833057403564, -14.5064268112183], [31.7112617492676, -14.5000152587891], [31.7365474700928, -14.4942140579224], [31.7488136291504, -14.4943628311157], [31.7509689331055, -14.4918622970581], [31.7786558168091, -14.4856062365029], [31.798202, -14.476412], [31.858173, -14.45577], [31.8611105889852, -14.4550566957263], [31.9292430877686, -14.4202003479004], [31.9318504333496, -14.4188661575317], [31.9477252960205, -14.4128446578979], [31.9511833190918, -14.4118032455444], [31.9756546020508, -14.4044322967529], [32.0316886901855, -14.3924245834351], [32.0562591552734, -14.3887910842896], [32.076057434082, -14.3798551559448], [32.0975036621094, -14.3701734542847], [32.1592826843262, -14.3494710922241], [32.163990020752, -14.3499813079834], [32.1825141906738, -14.3419923782349], [32.1827087402344, -14.341908454895], [32.1976432800293, -14.337984085083], [32.2054100036621, -14.3359441757202], [32.2423324584961, -14.3230028152466], [32.2831916809082, -14.3145217895508], [32.3151092529297, -14.3078956604004], [32.3212661743164, -14.3054304122925], [32.3225402832031, -14.3053550720215], [32.3344764709473, -14.3046445846558], [32.3581047058105, -14.299596786499], [32.3958778381348, -14.2944574356079], [32.449951171875, -14.2830724716187], [32.4511566162109, -14.2828178405762], [32.5271644592285, -14.248384475708], [32.5356674194336, -14.2463960647583], [32.5684814453125, -14.2324304580688], [32.6106872558594, -14.2144584655762], [32.6548957824707, -14.1994600296021], [32.6780776977539, -14.1897850036621], [32.6892356872559, -14.1871156692505], [32.6901245117188, -14.1869039535522], [32.7593879699707, -14.1622276306152], [32.7941436767578, -14.148736000061], [32.8107566833496, -14.1434106826782], [32.8430480957031, -14.1330575942993], [32.914176940918, -14.1074390411377], [32.9217224121094, -14.1063508987427], [32.9328498840332, -14.1017456054688], [32.934253692627, -14.1011648178101], [32.947940826416, -14.0978269577026], [33.0544662475586, -14.0585613250732], [33.0700798034668, -14.0528030395508], [33.0844993591309, -14.0457859039307], [33.175838470459, -14.014856338501], [33.2090072631836, -14.0036163330078], [33.1967582702637, -13.9921283721924], [33.1890907287598, -13.9780540466309], [33.1890926894387, -13.9777728059111], [33.159837, -13.973227], [33.1033, -13.988019], [33.071016, -14.037344], [33.029304, -14.059286], [32.939112, -14.01268], [32.916591, -13.966096], [32.868521, -13.901812], [32.821654, -13.847928], [32.816269912905, -13.840987527477], [32.795228, -13.813863], [32.7869289217103, -13.7758125257388], [32.7839622497559, -13.7749261856079], [ ...

# %%
aoi = ee_feature_collection.geometry()
start_date = "2023-01-01"
end_date = "2025-01-29"
output_folder_pentad = os.path.join(os.getcwd(), "data", "pixel data")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
from utils.chirps_collect_export import collect_and_export_chirps

collect_and_export_chirps(start_date, end_date, output_folder_pentad, aoi, data_type="PENTAD")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230101_y2023m01p01_Precipitation.csv created successfully.
# Exported 20230101_y2023m01p01_Precipitation in 0.61 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230106_y2023m01p02_Precipitation.csv created successfully.
# Exported 20230106_y2023m01p02_Precipitation in 0.46 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230111_y2023m01p03_Precipitation.csv created successfully.
# Exported 20230111_y2023m01p03_Precipitation in 0.41 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230116_y2023m01p04_Precipitation.csv created successfully.
# Exported 20230116_y2023m01p04_Precipitation in 0.51 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230121_y2023m01p05_Precipitation.csv created successfully.
# Exported 20230121_y2023m01p05_Precipitation in 0.64 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230126_y2023m01p06_Precipitation.csv created successfully.
# Exported 20230126_y2023m01p06_Precipitation in 0.65 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230201_y2023m02p01_Precipitation.csv created successfully.
# Exported 20230201_y2023m02p01_Precipitation in 0.49 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230206_y2023m02p02_Precipitation.csv created successfully.
# Exported 20230206_y2023m02p02_Precipitation in 0.63 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230211_y2023m02p03_Precipitation.csv created successfully.
# Exported 20230211_y2023m02p03_Precipitation in 0.53 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230216_y2023m02p04_Precipitation.csv created successfully.
# Exported 20230216_y2023m02p04_Precipitation in 0.64 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230221_y2023m02p05_Precipitation.csv created successfully.
# Exported 20230221_y2023m02p05_Precipitation in 0.58 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230226_y2023m02p06_Precipitation.csv created successfully.
# Exported 20230226_y2023m02p06_Precipitation in 0.45 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230301_y2023m03p01_Precipitation.csv created successfully.
# Exported 20230301_y2023m03p01_Precipitation in 0.53 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230306_y2023m03p02_Precipitation.csv created successfully.
# Exported 20230306_y2023m03p02_Precipitation in 0.53 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230311_y2023m03p03_Precipitation.csv created successfully.
# Exported 20230311_y2023m03p03_Precipitation in 0.42 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230316_y2023m03p04_Precipitation.csv created successfully.
# Exported 20230316_y2023m03p04_Precipitation in 0.56 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230321_y2023m03p05_Precipitation.csv created successfully.
# Exported 20230321_y2023m03p05_Precipitation in 0.54 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230326_y2023m03p06_Precipitation.csv created successfully.
# Exported 20230326_y2023m03p06_Precipitation in 0.55 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230401_y2023m04p01_Precipitation.csv created successfully.
# Exported 20230401_y2023m04p01_Precipitation in 0.66 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230406_y2023m04p02_Precipitation.csv created successfully.
# Exported 20230406_y2023m04p02_Precipitation in 0.52 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230411_y2023m04p03_Precipitation.csv created successfully.
# Exported 20230411_y2023m04p03_Precipitation in 0.57 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230416_y2023m04p04_Precipitation.csv created successfully.
# Exported 20230416_y2023m04p04_Precipitation in 0.53 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230421_y2023m04p05_Precipitation.csv created successfully.
# Exported 20230421_y2023m04p05_Precipitation in 0.45 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230426_y2023m04p06_Precipitation.csv created successfully.
# Exported 20230426_y2023m04p06_Precipitation in 0.4 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230501_y2023m05p01_Precipitation.csv created successfully.
# Exported 20230501_y2023m05p01_Precipitation in 0.51 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230506_y2023m05p02_Precipitation.csv created successfully.
# Exported 20230506_y2023m05p02_Precipitation in 0.53 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230511_y2023m05p03_Precipitation.csv created successfully.
# Exported 20230511_y2023m05p03_Precipitation in 0.56 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230516_y2023m05p04_Precipitation.csv created successfully.
# Exported 20230516_y2023m05p04_Precipitation in 0.46 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230521_y2023m05p05_Precipitation.csv created successfully.
# Exported 20230521_y2023m05p05_Precipitation in 0.56 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230526_y2023m05p06_Precipitation.csv created successfully.
# Exported 20230526_y2023m05p06_Precipitation in 0.57 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230601_y2023m06p01_Precipitation.csv created successfully.
# Exported 20230601_y2023m06p01_Precipitation in 0.52 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230606_y2023m06p02_Precipitation.csv created successfully.
# Exported 20230606_y2023m06p02_Precipitation in 0.51 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230611_y2023m06p03_Precipitation.csv created successfully.
# Exported 20230611_y2023m06p03_Precipitation in 0.44 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230616_y2023m06p04_Precipitation.csv created successfully.
# Exported 20230616_y2023m06p04_Precipitation in 0.58 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230621_y2023m06p05_Precipitation.csv created successfully.
# Exported 20230621_y2023m06p05_Precipitation in 0.37 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230626_y2023m06p06_Precipitation.csv created successfully.
# Exported 20230626_y2023m06p06_Precipitation in 0.41 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230701_y2023m07p01_Precipitation.csv created successfully.
# Exported 20230701_y2023m07p01_Precipitation in 0.41 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230706_y2023m07p02_Precipitation.csv created successfully.
# Exported 20230706_y2023m07p02_Precipitation in 0.63 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230711_y2023m07p03_Precipitation.csv created successfully.
# Exported 20230711_y2023m07p03_Precipitation in 0.39 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230716_y2023m07p04_Precipitation.csv created successfully.
# Exported 20230716_y2023m07p04_Precipitation in 0.56 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230721_y2023m07p05_Precipitation.csv created successfully.
# Exported 20230721_y2023m07p05_Precipitation in 0.48 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230726_y2023m07p06_Precipitation.csv created successfully.
# Exported 20230726_y2023m07p06_Precipitation in 0.53 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230801_y2023m08p01_Precipitation.csv created successfully.
# Exported 20230801_y2023m08p01_Precipitation in 0.52 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230806_y2023m08p02_Precipitation.csv created successfully.
# Exported 20230806_y2023m08p02_Precipitation in 0.46 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230811_y2023m08p03_Precipitation.csv created successfully.
# Exported 20230811_y2023m08p03_Precipitation in 0.53 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230816_y2023m08p04_Precipitation.csv created successfully.
# Exported 20230816_y2023m08p04_Precipitation in 0.45 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230821_y2023m08p05_Precipitation.csv created successfully.
# Exported 20230821_y2023m08p05_Precipitation in 0.58 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230826_y2023m08p06_Precipitation.csv created successfully.
# Exported 20230826_y2023m08p06_Precipitation in 0.35 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230901_y2023m09p01_Precipitation.csv created successfully.
# Exported 20230901_y2023m09p01_Precipitation in 0.48 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230906_y2023m09p02_Precipitation.csv created successfully.
# Exported 20230906_y2023m09p02_Precipitation in 0.52 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230911_y2023m09p03_Precipitation.csv created successfully.
# Exported 20230911_y2023m09p03_Precipitation in 0.43 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230916_y2023m09p04_Precipitation.csv created successfully.
# Exported 20230916_y2023m09p04_Precipitation in 0.47 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230921_y2023m09p05_Precipitation.csv created successfully.
# Exported 20230921_y2023m09p05_Precipitation in 0.49 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20230926_y2023m09p06_Precipitation.csv created successfully.
# Exported 20230926_y2023m09p06_Precipitation in 0.59 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20231001_y2023m10p01_Precipitation.csv created successfully.
# Exported 20231001_y2023m10p01_Precipitation in 0.51 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20231006_y2023m10p02_Precipitation.csv created successfully.
# Exported 20231006_y2023m10p02_Precipitation in 0.37 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20231011_y2023m10p03_Precipitation.csv created successfully.
# Exported 20231011_y2023m10p03_Precipitation in 0.55 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20231016_y2023m10p04_Precipitation.csv created successfully.
# Exported 20231016_y2023m10p04_Precipitation in 0.52 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20231021_y2023m10p05_Precipitation.csv created successfully.
# Exported 20231021_y2023m10p05_Precipitation in 0.37 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20231026_y2023m10p06_Precipitation.csv created successfully.
# Exported 20231026_y2023m10p06_Precipitation in 0.53 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20231101_y2023m11p01_Precipitation.csv created successfully.
# Exported 20231101_y2023m11p01_Precipitation in 0.58 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20231106_y2023m11p02_Precipitation.csv created successfully.
# Exported 20231106_y2023m11p02_Precipitation in 0.57 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20231111_y2023m11p03_Precipitation.csv created successfully.
# Exported 20231111_y2023m11p03_Precipitation in 0.46 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20231116_y2023m11p04_Precipitation.csv created successfully.
# Exported 20231116_y2023m11p04_Precipitation in 0.57 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20231121_y2023m11p05_Precipitation.csv created successfully.
# Exported 20231121_y2023m11p05_Precipitation in 0.46 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20231126_y2023m11p06_Precipitation.csv created successfully.
# Exported 20231126_y2023m11p06_Precipitation in 0.56 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20231201_y2023m12p01_Precipitation.csv created successfully.
# Exported 20231201_y2023m12p01_Precipitation in 0.47 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20231206_y2023m12p02_Precipitation.csv created successfully.
# Exported 20231206_y2023m12p02_Precipitation in 0.55 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20231211_y2023m12p03_Precipitation.csv created successfully.
# Exported 20231211_y2023m12p03_Precipitation in 0.35 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20231216_y2023m12p04_Precipitation.csv created successfully.
# Exported 20231216_y2023m12p04_Precipitation in 0.62 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20231221_y2023m12p05_Precipitation.csv created successfully.
# Exported 20231221_y2023m12p05_Precipitation in 0.48 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20231226_y2023m12p06_Precipitation.csv created successfully.
# Exported 20231226_y2023m12p06_Precipitation in 0.48 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240101_y2024m01p01_Precipitation.csv created successfully.
# Exported 20240101_y2024m01p01_Precipitation in 0.53 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240106_y2024m01p02_Precipitation.csv created successfully.
# Exported 20240106_y2024m01p02_Precipitation in 0.37 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240111_y2024m01p03_Precipitation.csv created successfully.
# Exported 20240111_y2024m01p03_Precipitation in 0.49 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240116_y2024m01p04_Precipitation.csv created successfully.
# Exported 20240116_y2024m01p04_Precipitation in 0.37 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240121_y2024m01p05_Precipitation.csv created successfully.
# Exported 20240121_y2024m01p05_Precipitation in 0.58 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240126_y2024m01p06_Precipitation.csv created successfully.
# Exported 20240126_y2024m01p06_Precipitation in 0.5 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240201_y2024m02p01_Precipitation.csv created successfully.
# Exported 20240201_y2024m02p01_Precipitation in 0.56 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240206_y2024m02p02_Precipitation.csv created successfully.
# Exported 20240206_y2024m02p02_Precipitation in 0.47 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240211_y2024m02p03_Precipitation.csv created successfully.
# Exported 20240211_y2024m02p03_Precipitation in 0.51 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240216_y2024m02p04_Precipitation.csv created successfully.
# Exported 20240216_y2024m02p04_Precipitation in 0.52 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240221_y2024m02p05_Precipitation.csv created successfully.
# Exported 20240221_y2024m02p05_Precipitation in 0.41 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240226_y2024m02p06_Precipitation.csv created successfully.
# Exported 20240226_y2024m02p06_Precipitation in 0.56 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240301_y2024m03p01_Precipitation.csv created successfully.
# Exported 20240301_y2024m03p01_Precipitation in 0.6 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240306_y2024m03p02_Precipitation.csv created successfully.
# Exported 20240306_y2024m03p02_Precipitation in 0.56 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240311_y2024m03p03_Precipitation.csv created successfully.
# Exported 20240311_y2024m03p03_Precipitation in 0.44 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240316_y2024m03p04_Precipitation.csv created successfully.
# Exported 20240316_y2024m03p04_Precipitation in 0.38 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240321_y2024m03p05_Precipitation.csv created successfully.
# Exported 20240321_y2024m03p05_Precipitation in 0.44 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240326_y2024m03p06_Precipitation.csv created successfully.
# Exported 20240326_y2024m03p06_Precipitation in 0.44 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240401_y2024m04p01_Precipitation.csv created successfully.
# Exported 20240401_y2024m04p01_Precipitation in 0.35 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240406_y2024m04p02_Precipitation.csv created successfully.
# Exported 20240406_y2024m04p02_Precipitation in 0.43 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240411_y2024m04p03_Precipitation.csv created successfully.
# Exported 20240411_y2024m04p03_Precipitation in 0.56 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240416_y2024m04p04_Precipitation.csv created successfully.
# Exported 20240416_y2024m04p04_Precipitation in 0.55 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240421_y2024m04p05_Precipitation.csv created successfully.
# Exported 20240421_y2024m04p05_Precipitation in 0.35 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240426_y2024m04p06_Precipitation.csv created successfully.
# Exported 20240426_y2024m04p06_Precipitation in 0.52 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240501_y2024m05p01_Precipitation.csv created successfully.
# Exported 20240501_y2024m05p01_Precipitation in 0.5 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240506_y2024m05p02_Precipitation.csv created successfully.
# Exported 20240506_y2024m05p02_Precipitation in 0.45 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240511_y2024m05p03_Precipitation.csv created successfully.
# Exported 20240511_y2024m05p03_Precipitation in 0.56 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240516_y2024m05p04_Precipitation.csv created successfully.
# Exported 20240516_y2024m05p04_Precipitation in 0.5 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240521_y2024m05p05_Precipitation.csv created successfully.
# Exported 20240521_y2024m05p05_Precipitation in 0.62 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240526_y2024m05p06_Precipitation.csv created successfully.
# Exported 20240526_y2024m05p06_Precipitation in 0.53 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240601_y2024m06p01_Precipitation.csv created successfully.
# Exported 20240601_y2024m06p01_Precipitation in 0.63 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240606_y2024m06p02_Precipitation.csv created successfully.
# Exported 20240606_y2024m06p02_Precipitation in 0.55 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240611_y2024m06p03_Precipitation.csv created successfully.
# Exported 20240611_y2024m06p03_Precipitation in 0.32 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240616_y2024m06p04_Precipitation.csv created successfully.
# Exported 20240616_y2024m06p04_Precipitation in 0.52 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240621_y2024m06p05_Precipitation.csv created successfully.
# Exported 20240621_y2024m06p05_Precipitation in 0.53 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240626_y2024m06p06_Precipitation.csv created successfully.
# Exported 20240626_y2024m06p06_Precipitation in 0.4 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240701_y2024m07p01_Precipitation.csv created successfully.
# Exported 20240701_y2024m07p01_Precipitation in 0.51 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240706_y2024m07p02_Precipitation.csv created successfully.
# Exported 20240706_y2024m07p02_Precipitation in 0.42 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240711_y2024m07p03_Precipitation.csv created successfully.
# Exported 20240711_y2024m07p03_Precipitation in 0.53 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240716_y2024m07p04_Precipitation.csv created successfully.
# Exported 20240716_y2024m07p04_Precipitation in 0.59 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240721_y2024m07p05_Precipitation.csv created successfully.
# Exported 20240721_y2024m07p05_Precipitation in 0.44 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240726_y2024m07p06_Precipitation.csv created successfully.
# Exported 20240726_y2024m07p06_Precipitation in 0.63 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240801_y2024m08p01_Precipitation.csv created successfully.
# Exported 20240801_y2024m08p01_Precipitation in 0.39 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240806_y2024m08p02_Precipitation.csv created successfully.
# Exported 20240806_y2024m08p02_Precipitation in 0.41 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240811_y2024m08p03_Precipitation.csv created successfully.
# Exported 20240811_y2024m08p03_Precipitation in 0.59 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240816_y2024m08p04_Precipitation.csv created successfully.
# Exported 20240816_y2024m08p04_Precipitation in 0.57 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240821_y2024m08p05_Precipitation.csv created successfully.
# Exported 20240821_y2024m08p05_Precipitation in 0.54 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240826_y2024m08p06_Precipitation.csv created successfully.
# Exported 20240826_y2024m08p06_Precipitation in 0.56 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240901_y2024m09p01_Precipitation.csv created successfully.
# Exported 20240901_y2024m09p01_Precipitation in 0.41 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240906_y2024m09p02_Precipitation.csv created successfully.
# Exported 20240906_y2024m09p02_Precipitation in 0.46 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240911_y2024m09p03_Precipitation.csv created successfully.
# Exported 20240911_y2024m09p03_Precipitation in 0.34 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240916_y2024m09p04_Precipitation.csv created successfully.
# Exported 20240916_y2024m09p04_Precipitation in 0.42 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240921_y2024m09p05_Precipitation.csv created successfully.
# Exported 20240921_y2024m09p05_Precipitation in 0.48 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20240926_y2024m09p06_Precipitation.csv created successfully.
# Exported 20240926_y2024m09p06_Precipitation in 0.58 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20241001_y2024m10p01_Precipitation.csv created successfully.
# Exported 20241001_y2024m10p01_Precipitation in 0.38 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20241006_y2024m10p02_Precipitation.csv created successfully.
# Exported 20241006_y2024m10p02_Precipitation in 0.53 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20241011_y2024m10p03_Precipitation.csv created successfully.
# Exported 20241011_y2024m10p03_Precipitation in 0.53 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20241016_y2024m10p04_Precipitation.csv created successfully.
# Exported 20241016_y2024m10p04_Precipitation in 0.46 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20241021_y2024m10p05_Precipitation.csv created successfully.
# Exported 20241021_y2024m10p05_Precipitation in 0.56 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20241026_y2024m10p06_Precipitation.csv created successfully.
# Exported 20241026_y2024m10p06_Precipitation in 0.47 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20241101_y2024m11p01_Precipitation.csv created successfully.
# Exported 20241101_y2024m11p01_Precipitation in 0.48 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20241106_y2024m11p02_Precipitation.csv created successfully.
# Exported 20241106_y2024m11p02_Precipitation in 0.4 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20241111_y2024m11p03_Precipitation.csv created successfully.
# Exported 20241111_y2024m11p03_Precipitation in 0.59 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20241116_y2024m11p04_Precipitation.csv created successfully.
# Exported 20241116_y2024m11p04_Precipitation in 0.41 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20241121_y2024m11p05_Precipitation.csv created successfully.
# Exported 20241121_y2024m11p05_Precipitation in 0.62 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20241126_y2024m11p06_Precipitation.csv created successfully.
# Exported 20241126_y2024m11p06_Precipitation in 0.44 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20241201_y2024m12p01_Precipitation.csv created successfully.
# Exported 20241201_y2024m12p01_Precipitation in 0.52 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20241206_y2024m12p02_Precipitation.csv created successfully.
# Exported 20241206_y2024m12p02_Precipitation in 0.47 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20241211_y2024m12p03_Precipitation.csv created successfully.
# Exported 20241211_y2024m12p03_Precipitation in 0.47 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20241216_y2024m12p04_Precipitation.csv created successfully.
# Exported 20241216_y2024m12p04_Precipitation in 0.56 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20241221_y2024m12p05_Precipitation.csv created successfully.
# Exported 20241221_y2024m12p05_Precipitation in 0.54 seconds.
# File /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/20241226_y2024m12p06_Precipitation.csv created successfully.
# Exported 20241226_y2024m12p06_Precipitation in 0.32 seconds.
# Exported longitude to /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/AOI_longitude.csv
# Exported latitude to /Users/samuelgartenstein/Desktop/zambia-drought-analysis/data/pixel data/AOI_latitude.csv
# Total time taken: 73.45 seconds.
